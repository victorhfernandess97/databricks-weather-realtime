-- %%
USE CATALOG weather_realtime

-- %%
GRANT USAGE ON CATALOG weather_realtime TO `dataeng.victor@outlook.com`;
GRANT CREATE ON CATALOG weather_realtime TO `dataeng.victor@outlook.com`;

GRANT USAGE, CREATE ON SCHEMA weather_realtime.bronze TO `dataeng.victor@outlook.com`;
GRANT USAGE, CREATE ON SCHEMA weather_realtime.silver TO `dataeng.victor@outlook.com`;
GRANT USAGE, CREATE ON SCHEMA weather_realtime.gold TO `dataeng.victor@outlook.com`;

-- %%
SHOW EXTERNAL LOCATIONS;

-- %%
SHOW VOLUMES IN weather_realtime.bronze;
